# %% [markdown]
# <center><h1>INDUSTRIAL TRAINING PROJECT</h1><h3>DATA SCIENCE
# TELLING STORIES WITH DATA
# </h3></center>

# %%
# importing libraries
import pandas as pd
import numpy as np               
import seaborn as sns              
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# loading the data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.shape
# Out:
# (31647, 18)

# %%
test.shape
# Out:
# (13564, 17)

# %%
train.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'subscribed'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome'],
#       dtype='object')

# %%
print(train.dtypes)
test.dtypes
# Out:
# ID             int64
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# subscribed    object
# dtype: object
# ID            int64
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# dtype: object

# %%
train.head()
# Out:
#       ID  age         job   marital  education default  balance housing loan  \
# 0  26110   56      admin.   married    unknown      no     1933      no   no
# 1  40576   31     unknown   married  secondary      no        3      no   no
# 2  15320   27    services   married  secondary      no      891     yes   no
# 3  43962   57  management  divorced   tertiary      no     3287      no   no
# 4  29842   31  technician   married  secondary      no      119     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   19   nov        44         2     -1         0  unknown
# 1   cellular   20   jul        91         2     -1         0  unknown
# 2   cellular   18   jul       240         1     -1         0  unknown
# 3   cellular   22   jun       867         1     84         3  success
# 4   cellular    4   feb       380         1     -1         0  unknown
#
#   subscribed
# 0         no
# 1         no
# 2         no
# 3        yes
# 4         no

# %%
train['poutcome'].value_counts()
# Out:
# unknown    25929
# failure     3362
# other       1288
# success     1068
# Name: poutcome, dtype: int64

# %% [markdown]
# # Univariant & Bivariant Analysis

# %%
train['subscribed'].value_counts()
# Out:
# no     27932
# yes     3715
# Name: subscribed, dtype: int64

# %%
# plotting the bar plot of frequencies
train['subscribed'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
 
train['subscribed'].value_counts(normalize=True)
# Out:
# no     0.882611
# yes    0.117389
# Name: subscribed, dtype: float64

# %% [markdown]
# around 12% ussers are subscribed.

# %%
sns.histplot(train["age"])
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %% [markdown]
# Maximum Users are from 20 to 60 age group.

# %%
train["marital"].value_counts(normalize= True )
# Out:
# married     0.603375
# single      0.281922
# divorced    0.114703
# Name: marital, dtype: float64

# %%
train.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'subscribed'],
#       dtype='object')

# %%
print(train['loan'].value_counts(normalize = True))
train['loan'].value_counts().plot.bar()
# Out:
# no     0.837868
# yes    0.162132
# Name: loan, dtype: float64
# <AxesSubplot: >

# %% [markdown]
# Aroun 16% user having Personal Loan.

# %%
print(train['housing'].value_counts())
train['housing'].value_counts().plot.bar()
# Out:
# yes    17584
# no     14063
# Name: housing, dtype: int64
# <AxesSubplot: >

# %%
print(train['education'].value_counts())
train['education'].value_counts().plot.bar()
# Out:
# secondary    16224
# tertiary      9301
# primary       4808
# unknown       1314
# Name: education, dtype: int64
# <AxesSubplot: >

# %%
print(train['job'].value_counts())
train['job'].value_counts().plot.bar()
# Out:
# blue-collar      6842
# management       6639
# technician       5307
# admin.           3631
# services         2903
# retired          1574
# self-employed    1123
# entrepreneur     1008
# unemployed        905
# housemaid         874
# student           635
# unknown           206
# Name: job, dtype: int64
# <AxesSubplot: >

# %% [markdown]
# Most of the Users are from 'blue-collar' job and least users are students.

# %%
train['default'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
train['default'].value_counts(normalize=True)
# Out:
# no     0.981515
# yes    0.018485
# Name: default, dtype: float64

# %% [markdown]
# Only around 2% User having credit in defaults

# %%
job=pd.crosstab(train['job'],train['subscribed'])
job
# Out:
# subscribed       no  yes
# job
# admin.         3179  452
# blue-collar    6353  489
# entrepreneur    923   85
# housemaid       795   79
# management     5716  923
# retired        1212  362
# self-employed   983  140
# services       2649  254
# student         453  182
# technician     4713  594
# unemployed      776  129
# unknown         180   26

# %%
job.div(job.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(8,8))
plt.xlabel('Job')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# Data set Shows Students and Retired Users having higher chances to Subcribing term deposits.

# %%
loan=pd.crosstab(train['loan'],train['subscribed'])
print(loan)
loan.div(loan.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(8,8))
plt.xlabel('Personal Loan')
plt.ylabel('Percentage')
# Out:
# subscribed     no   yes
# loan
# no          23132  3384
# yes          4800   331
# Text(0, 0.5, 'Percentage')

# %%
housing=pd.crosstab(train['housing'],train['subscribed'])
print(housing)
housing.div(housing.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(8,8))
plt.xlabel('housing Loan')
plt.ylabel('Percentage')
# Out:
# subscribed     no   yes
# housing
# no          11698  2365
# yes         16234  1350
# Text(0, 0.5, 'Percentage')

# %%
default=pd.crosstab(train['default'],train['subscribed'])
print(default)
default.div(default.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(8,8))
plt.xlabel('default')
plt.ylabel('Percentage')
# Out:
# subscribed     no   yes
# default
# no          27388  3674
# yes           544    41
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# Those user not Having Credit in default have slighty higher Chance to Subscribing term deposits.

# %%
train['subscribed'].replace('no', 0,inplace=True)
train['subscribed'].replace('yes', 1,inplace=True)
train['loan'].replace('yes',1,inplace=True)
train['loan'].replace('no',0,inplace=True)

# %%
sub_to_loan_df = train[['subscribed','loan']]
sub_to_loan_df
# Out:
#        subscribed  loan
# 0               0     0
# 1               0     0
# 2               0     0
# 3               1     0
# 4               0     0
# ...           ...   ...
# 31642           0     0
# 31643           1     1
# 31644           0     0
# 31645           0     0
# 31646           1     0
#
# [31647 rows x 2 columns]

# %%
corr = sub_to_loan_df.corr()
mask = np.array(corr)
mask[np.tril_indices_from(mask)] = False
fig,ax= plt.subplots()
fig.set_size_inches(20,10)
sns.heatmap(corr, mask=mask,vmax=.9, square=True,annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot: >

# %%
corr = train.corr()
mask = np.array(corr)
mask[np.tril_indices_from(mask)] = False
fig,ax= plt.subplots()
fig.set_size_inches(20,10)
sns.heatmap(corr, mask=mask,vmax=.9, square=True,annot=True, cmap="YlGnBu")
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_3948\180198717.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = train.corr()
# <AxesSubplot: >

# %% [markdown]
# Not abble to see any high correlation except duration and subscribed. it shows more talk time, User shows more interest in term deposits.

# %%
train.isna().sum()
# Out:
# ID            0
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
print(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          31647 non-null  int64
#  1   age         31647 non-null  int64
#  2   job         31647 non-null  object
#  3   marital     31647 non-null  object
#  4   education   31647 non-null  object
#  5   default     31647 non-null  object
#  6   balance     31647 non-null  int64
#  7   housing     31647 non-null  object
#  8   loan        31647 non-null  int64
#  9   contact     31647 non-null  object
#  10  day         31647 non-null  int64
#  11  month       31647 non-null  object
#  12  duration    31647 non-null  int64
#  13  campaign    31647 non-null  int64
#  14  pdays       31647 non-null  int64
#  15  previous    31647 non-null  int64
#  16  poutcome    31647 non-null  object
#  17  subscribed  31647 non-null  int64
# dtypes: int64(10), object(8)
# memory usage: 4.3+ MB
# None

# %% [markdown]
# # Model Building

# %%
target = train['subscribed']
train = train.drop('subscribed',1)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_3948\461833753.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   train = train.drop('subscribed',1)

# %%
# applying dummies on the train dataset
train = pd.get_dummies(train)

# %%
from sklearn.model_selection import train_test_split
# splitting into train and validation with 20% data in validation set and 80% data in train set.
X_train, X_val, y_train, y_val = train_test_split(train, target, test_size = 0.2, random_state=12)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=4, random_state=0)
clf.fit(X_train,y_train)
plt.figure(figsize=(15,10))
tree.plot_tree(clf,filled=True)
# Out:
# [Text(0.5, 0.9, 'X[0] <= 39786.5\ngini = 0.208\nsamples = 25317\nvalue = [22324, 2993]'),
#  Text(0.25, 0.7, 'X[5] <= 609.5\ngini = 0.131\nsamples = 22246\nvalue = [20682, 1564]'),
#  Text(0.125, 0.5, 'X[5] <= 452.5\ngini = 0.069\nsamples = 20464\nvalue = [19735, 729]'),
#  Text(0.0625, 0.3, 'X[42] <= 0.5\ngini = 0.049\nsamples = 19151\nvalue = [18668, 483]'),
#  Text(0.03125, 0.1, 'gini = 0.043\nsamples = 19020\nvalue = [18603, 417]'),
#  Text(0.09375, 0.1, 'gini = 0.5\nsamples = 131\nvalue = [65, 66]'),
#  Text(0.1875, 0.3, 'X[0] <= 33692.0\ngini = 0.305\nsamples = 1313\nvalue = [1067, 246]'),
#  Text(0.15625, 0.1, 'gini = 0.264\nsamples = 1082\nvalue = [913, 169]'),
#  Text(0.21875, 0.1, 'gini = 0.444\nsamples = 231\nvalue = [154, 77]'),
#  Text(0.375, 0.5, 'X[5] <= 869.5\ngini = 0.498\nsamples = 1782\nvalue = [947, 835]'),
#  Text(0.3125, 0.3, 'X[0] <= 33782.5\ngini = 0.471\nsamples = 1008\nvalue = [625, 383]'),
#  Text(0.28125, 0.1, 'gini = 0.444\nsamples = 858\nvalue = [573, 285]'),
#  Text(0.34375, 0.1, 'gini = 0.453\nsamples = 150\nvalue = [52, 98]'),
#  Text(0.4375, 0.3, 'X[0] <= 3434.0\ngini = 0.486\nsamples = 774\nvalue = [322, 452]'),
#  Text(0.40625, 0.1, 'gini = 0.448\nsamples = 65\nvalue = [43, 22]'),
#  Text(0.46875, 0.1, 'gini = 0.477\nsamples = 709\nvalue = [279, 430]'),
#  Text(0.75, 0.7, 'X[5] <= 163.5\ngini = 0.498\nsamples = 3071\nvalue = [1642, 1429]'),
#  Text(0.625, 0.5, 'X[5] <= 117.5\ngini = 0.271\nsamples = 1041\nvalue = [873, 168]'),
#  Text(0.5625, 0.3, 'X[49] <= 0.5\ngini = 0.168\nsamples = 606\nvalue = [550, 56]'),
#  Text(0.53125, 0.1, 'gini = 0.125\nsamples = 539\nvalue = [503, 36]'),
#  Text(0.59375, 0.1, 'gini = 0.419\nsamples = 67\nvalue = [47, 20]'),
#  Text(0.6875, 0.3, 'X[0] <= 43494.5\ngini = 0.382\nsamples = 435\nvalue = [323, 112]'),
#  Text(0.65625, 0.1, 'gini = 0.427\nsamples = 336\nvalue = [232, 104]'),
#  Text(0.71875, 0.1, 'gini = 0.149\nsamples = 99\nvalue = [91, 8]'),
#  Text(0.875, 0.5, 'X[49] <= 0.5\ngini = 0.471\nsamples = 2030\nvalue = [769, 1261]'),
#  Text(0.8125, 0.3, 'X[5] <= 206.5\ngini = 0.496\nsamples = 1481\nvalue = [675, 806]'),
#  Text(0.78125, 0.1, 'gini = 0.459\nsamples = 278\nvalue = [179, 99]'),
#  Text(0.84375, 0.1, 'gini = 0.485\nsamples = 1203\nvalue = [496, 707]'),
#  Text(0.9375, 0.3, 'X[0] <= 41013.0\ngini = 0.284\nsamples = 549\nvalue = [94, 455]'),
#  Text(0.90625, 0.1, 'gini = 0.463\nsamples = 55\nvalue = [20, 35]'),
#  Text(0.96875, 0.1, 'gini = 0.255\nsamples = 494\nvalue = [74, 420]')]

# %%
# making prediction on the validation set
predict = clf.predict(X_val)
predict
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
#accuracy of model creation
clf.score(X_train, y_train)
# Out:
# 0.9121933878421614

# %%
#accuracy on validation 
clf.score(X_val, y_val)
# Out:
# 0.9042654028436019

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_val, predict)
# Out:
# 0.9042654028436019

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=18)
classifier.fit (X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=18)

# %%
y_pred= classifier.predict(X_val)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
#accuracy of model creation
classifier.score(X_train, y_train)
# Out:
# 0.997393056049295

# %%
#accuracy on validation 
classifier.score(X_val, y_val)
# Out:
# 0.9041074249605056

# %%
accuracy_score(y_val, y_pred)
# Out:
# 0.9041074249605056

# %% [markdown]
# Using both model getting around Same Result.

# %% [markdown]
# <center><h1>Testing Model</h1></center>

# %%
test = pd.get_dummies(test)
test_prediction = classifier.predict(test)
submission = pd.DataFrame()

# %%
# creating a Business_Sourced column and saving the predictions in it
submission['ID'] = test['ID']
submission['subscribed'] = test_prediction

# %%
submission['subscribed'].replace(0,'no',inplace=True)
submission['subscribed'].replace(1,'yes',inplace=True)
submission
# Out:
#           ID subscribed
# 0      26110         no
# 1      40576         no
# 2      15320         no
# 3      43962        yes
# 4      29842         no
# ...      ...        ...
# 31642  36483         no
# 31643  40178        yes
# 31644  19710         no
# 31645  38556         no
# 31646  14156        yes
#
# [31647 rows x 2 columns]

# %%
submission.to_csv('submission.csv', header=True, index=False)
